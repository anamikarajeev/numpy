# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\ANAMIKA\Downloads\Titanic-Dataset.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.ndim
# Out:
# 2

# %%
df1.shape
# Out:
# (891, 12)

# %%
df1.size
# Out:
# 10692

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df1.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1.describe(include='object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
df1[['PassengerId','Name','Age','Sex','Survived']]
# Out:
#      PassengerId                                               Name   Age  \
# 0              1                            Braund, Mr. Owen Harris  22.0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2              3                             Heikkinen, Miss. Laina  26.0
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5                           Allen, Mr. William Henry  35.0
# ..           ...                                                ...   ...
# 886          887                              Montvila, Rev. Juozas  27.0
# 887          888                       Graham, Miss. Margaret Edith  19.0
# 888          889           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889          890                              Behr, Mr. Karl Howell  26.0
# 890          891                                Dooley, Mr. Patrick  32.0
#
#         Sex  Survived
# 0      male         0
# 1    female         1
# ...

# %%
df1.loc[9]
# Out:
# PassengerId                                     10
# Survived                                         1
# Pclass                                           2
# Name           Nasser, Mrs. Nicholas (Adele Achem)
# Sex                                         female
# Age                                           14.0
# SibSp                                            1
# Parch                                            0
# Ticket                                      237736
# Fare                                       30.0708
# Cabin                                          NaN
# Embarked                                         C
# Name: 9, dtype: object

# %%
df1.loc[4:14]
# Out:
#     PassengerId  Survived  Pclass  \
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
df1.loc[19:29,['Name','Fare']]
# Out:
#                                                  Name      Fare
# 19                            Masselmani, Mrs. Fatima    7.2250
# 20                               Fynney, Mr. Joseph J   26.0000
# 21                              Beesley, Mr. Lawrence   13.0000
# 22                        McGowan, Miss. Anna "Annie"    8.0292
# 23                       Sloper, Mr. William Thompson   35.5000
# 24                      Palsson, Miss. Torborg Danira   21.0750
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   31.3875
# 26                            Emir, Mr. Farred Chehab    7.2250
# 27                     Fortune, Mr. Charles Alexander  263.0000
# 28                      O'Dwyer, Miss. Ellen "Nellie"    7.8792
# 29                                Todoroff, Mr. Lalio    7.8958

# %%
df1.iloc[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df1.iloc[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df1.iloc[2:12,1:5]
# Out:
#     Survived  Pclass                                               Name  \
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
#
#        Sex
# 2   female
# 3   female
# 4     male
# 5     male
# 6     male
# 7     male
# 8   female
# 9   female
# 10  female
# 11  female

# %%
df1["Ticket_Fare_Category"]="Medium"
df1.loc[df1["Fare"]<20,"Ticket_Fare_Category"]="Low"
df1.loc[df1["Fare"]>50,"Ticket_Fare_Category"]="High"
print(df1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.loc[df1["PassengerId"]==25,"Cabin"]="B101"
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df1.drop(["Ticket","Cabin"],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop([5,10,15])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived']==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
df['Survived']==0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
df['Age']>30
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df['Fare']>100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df.sort_values('Name',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 868          869         0       3            van Melkebeke, Mr. Philemon
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 286          287         1       3                de Mulder, Mr. Theodore
# ..           ...       ...     ...                                    ...
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 308          309         0       2                    Abelson, Mr. Samuel
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 845          846         0       3                    Abbing, Mr. Anthony
#
#         Sex   Age  SibSp  Parch     Fare Embarked Ticket_Fare_Category
# ...

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age']==df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age']==df['Age'].min()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df["Fare"]==df['Fare'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool
